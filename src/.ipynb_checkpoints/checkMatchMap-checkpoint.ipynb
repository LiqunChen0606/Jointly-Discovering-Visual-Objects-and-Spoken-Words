# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
x = sio.loadmat('./matrix.mat')['x']

# %%
test = x[0]
test /= test.max()
print(test.shape)
print(x.max(), x.min())
print(test.max(), test.min())
# Out:
# (14, 14, 128)
# 1809.2473 0.0
# 1.0 0.0

# %%
th = 0.3
for i in range(14):
    for j in range(14):
        for k in range(128):
            if test[i,j,k] > th:
                test[i,j,k] = 1
            else:
                test[i,j,k] = 0

# %%
zz,xx,yy = test.nonzero()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
# ax.plot3D(xx, yy, zz, 'gray')
ax.scatter3D(xx, yy, zz, c=zdata, cmap='Greens');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f87de8bd2b11> in <module>()
#       2 ax = plt.axes(projection='3d')
#       3 # ax.plot3D(xx, yy, zz, 'gray')
# ----> 4 ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
#
# NameError: name 'xdata' is not defined
